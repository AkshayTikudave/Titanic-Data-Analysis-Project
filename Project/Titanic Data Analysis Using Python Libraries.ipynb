# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
titanic = pd.read_csv("C:/Users/aksha/Downloads/Titanic-Dataset.csv")

# %%
titanic

# %% [markdown]
# # Number of Male and Female Survived using count plot

# %%
sns.countplot(data=titanic,x='Survived',hue='Sex',palette=['red','green'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# # Servival Based on Class

# %%
sns.countplot(data=titanic,x='Survived',hue='Pclass',palette=['green','yellow','red'])
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %%
titanic.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          891 non-null    int64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     891 non-null    object
# dtypes: float64(1), int64(6), object(5)
# memory usage: 83.7+ KB

# %%
titanic['Age'].dropna().plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
color = ['red','yellow','hotpink','black','green','blue','brown']
sns.countplot(data=titanic,x='SibSp',palette=color)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\2546936084.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(data=titanic,x='SibSp',palette=color)
# <Axes: xlabel='SibSp', ylabel='count'>

# %% [markdown]
# # Finding Unique Values

# %%
print(titanic['Embarked'].unique())
# Out:
# ['S' 'C' 'Q']

# %%
print(titanic['SibSp'].unique())
# Out:
# [1 0 3 4 2 5 8]

# %% [markdown]
# # Handling Missing Values

# %%
m1 = titanic['Age'].median(skipna=True)
m2 = titanic['Age'].mean(skipna=True)
print(m1)
print(m2)
# Out:
# 28.0
# 29.34567901234568

# %% [markdown]
# # Counting Missing Values in Age

# %%
a = sum(pd.isnull(titanic['Age']))
a
# Out:
# 0

# %%
titanic['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
len(titanic['PassengerId'])
# Out:
# 891

# %%
per = a / len(titanic['PassengerId'])
age_missing_percentage = per*100
age_missing_percentage
# Out:
# 0.0

# %%
round(age_missing_percentage,0)
# Out:
# 0.0

# %% [markdown]
# # Handling Missing Values from Sge,Embarked

# %%
titanic['Age'].fillna(28,inplace=True)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\1525607363.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Age'].fillna(28,inplace=True)

# %%
titanic['Age'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Age
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    int64
# dtypes: int64(1)
# memory usage: 7.1 KB

# %%
titanic['Embarked'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Embarked
# Non-Null Count  Dtype
# --------------  -----
# 889 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
titanic['Embarked'].fillna('S',inplace=True)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\2112065772.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   titanic['Embarked'].fillna('S',inplace=True)

# %%
titanic['Embarked'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 891 entries, 0 to 890
# Series name: Embarked
# Non-Null Count  Dtype
# --------------  -----
# 891 non-null    object
# dtypes: object(1)
# memory usage: 7.1+ KB

# %%
y2 = titanic['Age']

# %%
y2
# Out:
# 0      22
# 1      38
# 2      26
# 3      35
# 4      35
#        ..
# 886    27
# 887    19
# 888    28
# 889    26
# 890    32
# Name: Age, Length: 891, dtype: int64

# %%
import numpy as np
x2 = np.arange(len(y2))

# %%
plt.plot(x2,y2)
plt.show()

# %%
sns.lineplot(data=titanic,x='Survived',y='Age')
# Out:
# <Axes: xlabel='Survived', ylabel='Age'>

# %%
print(y2.mean())
# Out:
# 29.36158249158249

# %%
titanic['Survived']
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
survived_mean = titanic.query('Survived > 0')
print(int(survived_mean['Age'].mean()))
# Out:
# 28

# %%
not_survived_mean = titanic.query('Survived == 0')
print(int(not_survived_mean['Age'].mean()))
# Out:
# 30

# %%
sns.lineplot(data=titanic,x='Embarked',y='Age',hue='Survived')
# Out:
# <Axes: xlabel='Embarked', ylabel='Age'>

# %%
category_order = ['S','C','Q']
color = ['red','green','blue']
sns.catplot(data=titanic,x='Embarked',kind='count',order=category_order,palette=color)
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\1570958625.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(data=titanic,x='Embarked',kind='count',order=category_order,palette=color)

# %%
sns.barplot(data=titanic,x='Survived',y='Age',palette=['red','green'])
plt.show()
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\811445765.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=titanic,x='Survived',y='Age',palette=['red','green'])

# %%
sns.set_theme(style='whitegrid')

# %%
titanic_copy = [titanic]

for dataset in titanic_copy:
    mean = titanic['Age'].mean()
    std = titanic['Age'].std()
    is_null = dataset['Age'].isnull().sum()

    # Compute random numbers between the mean,std and is_null

    rand_age = np.random.randint(mean-std,mean+std,size=is_null)
    age_slice = dataset['Age'].copy()
    age_slice[np.isnan(age_slice)]=rand_age
    dataset['Age']=age_slice
    dataset['Age']=titanic['Age'].astype(int)

# %%
survived = 'survived'
not_survived = 'not survived'

fig,axes = plt.subplots(nrows=1,ncols=2,figsize=(16,8))
women = titanic[titanic['Sex']=='female']
men = titanic[titanic['Sex']=='male']
ax = sns.distplot(women[women['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[0],kde=False,color='green')
ax = sns.distplot(women[women['Survived']==0].Age.dropna(),bins=40,label=not_survived,ax=axes[0],kde=False,color='red')
ax.legend()
ax.set_title('Female')
ax = sns.distplot(men[men['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[1],kde=False,color='green')
ax = sns.distplot(men[men['Survived']==0].Age.dropna(),bins=40,label=not_survived,ax=axes[1],kde=False,color='red')
ax.legend()
_ = ax.set_title('Male')
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\204616930.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   ax = sns.distplot(women[women['Survived']==1].Age.dropna(),bins=18,label=survived,ax=axes[0],kde=False,color='green')
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\204616930.py:8: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# # Influncer of passneger class on survival

# %%
sns.barplot(data=titanic,x='Pclass',y='Survived',palette=['green','yellow','red'])
# Out:
# C:\Users\aksha\AppData\Local\Temp\ipykernel_24368\3031969857.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=titanic,x='Pclass',y='Survived',palette=['green','yellow','red'])
# <Axes: xlabel='Pclass', ylabel='Survived'>

# %%
plt.figure()
fig = titanic.groupby('Survived')['Pclass'].plot.hist(histtype='bar',alpha=0.8)
plt.legend(('Died','Survived'),fontsize=12)
plt.show()

# %% [markdown]
# # Embarked influence on survival

# %%
sns.set(style='darkgrid')
sns.countplot(data=titanic,x='Survived',hue='Embarked',palette='Set1')
# Out:
# <Axes: xlabel='Survived', ylabel='count'>
